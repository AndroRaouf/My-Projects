# %%
# !pip install rapidfuzz --quiet

import pandas as pd, numpy as np, re
from rapidfuzz import process, fuzz
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid", font_scale=1.1)

# تعريف الفايلات
AMAZON_FILE = "amazon_Headphones_and_earpods.csv"
NOON_FILE = "noon_Headphones_and_earpods.csv"
MATCH_THRESHOLD = 70  # نخفض الثreshold عشان نشوف كل التشابهات
BATCH_SIZE = 6

# قراءة البيانات
amazon = pd.read_csv(AMAZON_FILE)
noon = pd.read_csv(NOON_FILE)

def drop_junk_cols(df):
    """حذف الأعمدة غير المهمة"""
    mask = ~df.columns.str.contains("src|\(\d+\)|Unnamed|placeholder|image|carousel|link", regex=True, case=False)
    return df.loc[:, mask]

def find_column_like(df, patterns):
    """الباحث عن الأعمدة بناء على أنماط"""
    cols = df.columns.tolist()
    for p in patterns:
        for c in cols:
            if p.lower() in c.lower():
                return c
    text_cols = [c for c in cols if df[c].dtype == object]
    if text_cols:
        return text_cols[0]
    return None

def clean_numeric_series(s):
    """تنظيف البيانات الرقمية"""
    if s is None:
        return pd.Series([np.nan] * len(s))
    s = s.astype(str).str.replace(",", "", regex=False).str.strip()
    extracted = s.str.extract(r"([0-9]+(?:\.[0-9]+)?)")[0]
    return pd.to_numeric(extracted, errors="coerce")

def normalize_product_name(s):
    """توحيد تنسيق أسماء المنتجات"""
    s = str(s).lower()
    s = re.sub(r"package(ing)? may vary", " ", s)
    s = re.sub(r"\b(\d+\s*(ml|g|gm|kg|l|oz|cm|mm))\b", " ", s)
    s = re.sub(r"\b(ml|g|gm|kg|l|oz|pack|packs|pcs|piece|pieces|box|set)\b", " ", s)
    s = re.sub(r"[^a-z0-9\s]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

# تنظيف البيانات
amazon = drop_junk_cols(amazon)
noon = drop_junk_cols(noon)

# تحديد الأعمدة
a_product_col = find_column_like(amazon, ["product","title","name"])
a_price_col = find_column_like(amazon, ["price"])
a_rating_col = find_column_like(amazon, ["rating"])
a_reviews_col = find_column_like(amazon, ["reviews","review"])

n_product_col = find_column_like(noon, ["product","title","name"])
n_price_col = find_column_like(noon, ["price"])
n_old_col = find_column_like(noon, ["old_price","old"])
n_rating_col = find_column_like(noon, ["rating"])
n_reviews_col = find_column_like(noon, ["reviews","review"])

print("Amazon columns found:")
print(f"Product: {a_product_col}, Price: {a_price_col}, Rating: {a_rating_col}, Reviews: {a_reviews_col}")
print("\nNoon columns found:")
print(f"Product: {n_product_col}, Price: {n_price_col}, Old Price: {n_old_col}, Rating: {n_rating_col}, Reviews: {n_reviews_col}")

# تنظيف بيانات Amazon
amazon_clean = pd.DataFrame()
amazon_clean['Product_raw'] = amazon[a_product_col] if a_product_col else amazon.iloc[:, 2]
amazon_clean['Price_raw'] = amazon[a_price_col] if a_price_col else amazon.iloc[:, 6]
amazon_clean['Rating_raw'] = amazon[a_rating_col] if a_rating_col else amazon.iloc[:, 4]
amazon_clean['Reviews_raw'] = amazon[a_reviews_col] if a_reviews_col else amazon.iloc[:, 5]

# تنظيف بيانات Noon
noon_clean = pd.DataFrame()
noon_clean['Product_raw'] = noon[n_product_col] if n_product_col else noon.iloc[:, 3]
noon_clean['Price_raw'] = noon[n_price_col] if n_price_col else noon.iloc[:, 6]
noon_clean['OldPrice_raw'] = noon[n_old_col] if n_old_col else noon.iloc[:, 7]
noon_clean['Rating_raw'] = noon[n_rating_col] if n_rating_col else noon.iloc[:, 4]
noon_clean['Reviews_raw'] = noon[n_reviews_col] if n_reviews_col else noon.iloc[:, 5]

# تطبيع أسماء المنتجات
amazon_clean['Product_norm'] = amazon_clean['Product_raw'].fillna("").map(normalize_product_name)
noon_clean['Product_norm'] = noon_clean['Product_raw'].fillna("").map(normalize_product_name)

# تنظيف البيانات الرقمية
amazon_clean['Price'] = clean_numeric_series(amazon_clean['Price_raw'])
amazon_clean['Rating'] = clean_numeric_series(amazon_clean['Rating_raw'])
amazon_clean['Reviews'] = clean_numeric_series(amazon_clean['Reviews_raw'])

noon_clean['Price'] = clean_numeric_series(noon_clean['Price_raw'])
noon_clean['Old_Price'] = clean_numeric_series(noon_clean['OldPrice_raw'])
noon_clean['Rating'] = clean_numeric_series(noon_clean['Rating_raw'])
noon_clean['Reviews'] = clean_numeric_series(noon_clean['Reviews_raw'])

print(f"\nAmazon cleaned: {len(amazon_clean)} products")
print(f"Noon cleaned: {len(noon_clean)} products")

# عمل المطابقة بين المنتجات - بنخفض الثreshold عشان نشوف كل التشابهات
noon_choices = noon_clean['Product_norm'].fillna("").tolist()
results = []

print(f"\nMatching products with threshold: {MATCH_THRESHOLD}%")

for idx, row in amazon_clean.iterrows():
    a_name = row['Product_norm']
    if not a_name.strip():
        continue

    match = process.extractOne(a_name, noon_choices, scorer=fuzz.token_set_ratio)
    if match is None:
        continue

    best_name, score, match_index = match
    if score < MATCH_THRESHOLD:
        continue

    n_row = noon_clean.iloc[match_index]
    a_price = row['Price'] if not pd.isna(row['Price']) else np.nan
    n_price = n_row['Price'] if not pd.isna(n_row['Price']) else np.nan

    # حساب فرق السعر (Amazon - Noon)
    price_diff = (a_price - n_price) if (not np.isnan(a_price) and not np.isnan(n_price)) else np.nan

    # تحديد الأفضل بناء على السعر
    if np.isnan(price_diff):
        if not np.isnan(a_price) and np.isnan(n_price):
            best_opt = "Amazon"
        elif np.isnan(a_price) and not np.isnan(n_price):
            best_opt = "Noon"
        else:
            best_opt = "Unknown"
    else:
        best_opt = "Amazon" if a_price < n_price else "Noon"

    results.append({
        "Amazon_idx": idx,
        "Noon_idx": match_index,
        "Amazon_Product": row['Product_raw'],
        "Amazon_Price": a_price,
        "Amazon_Rating": row['Rating'],
        "Amazon_Reviews": row['Reviews'],
        "Noon_Product": n_row['Product_raw'],
        "Noon_Price": n_price,
        "Noon_Old_Price": n_row['Old_Price'],
        "Noon_Rating": n_row['Rating'],
        "Noon_Reviews": n_row['Reviews'],
        "Match_Score": score,
        "Price_Diff_Amazon_Minus_Noon": price_diff,  # الكولوم الجديد
        "Best_Option": best_opt
    })

# إنشاء DataFrame النهائي
comparison = pd.DataFrame(results).sort_values("Match_Score", ascending=False).reset_index(drop=True)

# إضافة عمود يوضح فرق السعر بشكل أوضح
comparison['Price_Diff_EGP'] = comparison['Price_Diff_Amazon_Minus_Noon'].apply(
    lambda x: f"Amazon +{abs(x):.0f} EGP" if x > 0 else f"Noon +{abs(x):.0f} EGP" if x < 0 else "Same Price" if x == 0 else "N/A"
)

# حفظ النتائج
comparison.to_csv("Amazon_vs_Noon_comparison.csv", index=False)
comparison.to_excel("Amazon_vs_Noon_comparison.xlsx", index=False)

print(f"\n✅ Done. Total matches found: {len(comparison)}")
print(f"\n📊 All matched products ({len(comparison)} products):")

# عرض كل المنتجات المتشابهة
display(comparison[[
    'Amazon_Product',
    'Noon_Product',
    'Match_Score',
    'Amazon_Price',
    'Noon_Price',
    'Price_Diff_Amazon_Minus_Noon',
    'Price_Diff_EGP',
    'Best_Option'
]])

# دالة لعرض الرسوم البيانية
def plot_batches(df, batch_size=6):
    names = df["Amazon_Product"].astype(str).tolist()
    a_prices = df["Amazon_Price"].tolist()
    n_prices = df["Noon_Price"].tolist()
    price_diffs = df["Price_Diff_Amazon_Minus_Noon"].tolist()

    for i in range(0, len(names), batch_size):
        batch_names = names[i:i+batch_size]
        batch_a = a_prices[i:i+batch_size]
        batch_n = n_prices[i:i+batch_size]
        batch_diffs = price_diffs[i:i+batch_size]

        y = np.arange(len(batch_names))
        height = 0.35

        plt.figure(figsize=(14, max(5, len(batch_names)*0.9)))
        bars_a = plt.barh(y - height/2, batch_a, height=height, label="Amazon", color="#1f77b4", alpha=0.7)
        bars_n = plt.barh(y + height/2, batch_n, height=height, label="Noon", color="#ff7f0e", alpha=0.7)

        plt.yticks(y, [name[:50] + "..." if len(name) > 50 else name for name in batch_names], fontsize=8)
        plt.xlabel("Price (EGP)")
        plt.title(f"Amazon vs Noon Price Comparison - Batch {i//batch_size + 1}\n(Items {i+1}-{i+len(batch_names)}, Match Score: {df.iloc[i]['Match_Score']:.0f}%)")

        # إضافة القيم على الأعمدة
        for yi, av, nv, diff in zip(y, batch_a, batch_n, batch_diffs):
            if not pd.isna(av):
                plt.text(av, yi - height/2, f" {av:.0f}", va="center", fontsize=7, fontweight='bold')
            if not pd.isna(nv):
                plt.text(nv, yi + height/2, f" {nv:.0f}", va="center", fontsize=7, fontweight='bold')

            # إضافة فرق السعر في المنتصف
            if not pd.isna(diff):
                mid_x = min(av, nv) + abs(diff)/2
                color = "green" if diff < 0 else "red" if diff > 0 else "blue"
                plt.text(mid_x, yi, f"Δ={diff:.0f}", va="center", ha="center",
                        fontsize=8, fontweight='bold', color=color, bbox=dict(boxstyle="round,pad=0.2", facecolor="white", alpha=0.8))

        plt.legend()
        plt.tight_layout()
        plt.show()

# عرض الرسوم البيانية إذا وجدت نتائج
if not comparison.empty:
    plot_df = comparison.sort_values("Match_Score", ascending=False).reset_index(drop=True)
    plot_batches(plot_df, batch_size=BATCH_SIZE)

    # إحصائيات إضافية
    print("\n=== 📈 Comparison Statistics ===")
    print(f"Total matches: {len(comparison)}")
    print(f"Average match score: {comparison['Match_Score'].mean():.1f}%")

    amazon_cheaper = len(comparison[comparison['Best_Option'] == 'Amazon'])
    noon_cheaper = len(comparison[comparison['Best_Option'] == 'Noon'])
    same_price = len(comparison[(comparison['Price_Diff_Amazon_Minus_Noon'] == 0) & (~comparison['Price_Diff_Amazon_Minus_Noon'].isna())])

    print(f"📦 Amazon cheaper in: {amazon_cheaper} products")
    print(f"🛒 Noon cheaper in: {noon_cheaper} products")
    print(f"⚖️ Same price in: {same_price} products")

    if len(comparison) > 0:
        valid_diffs = comparison['Price_Diff_Amazon_Minus_Noon'].dropna()
        if len(valid_diffs) > 0:
            avg_price_diff = valid_diffs.mean()
            max_saving_amazon = valid_diffs.min()  # أكثر فرق إيجابي لصالح Amazon
            max_saving_noon = valid_diffs.max()    # أكثر فرق إيجابي لصالح Noon

            print(f"💰 Average price difference: {avg_price_diff:.2f} EGP (Amazon - Noon)")
            print(f"💸 Maximum saving on Amazon: {abs(max_saving_amazon):.0f} EGP")
            print(f"💸 Maximum saving on Noon: {abs(max_saving_noon):.0f} EGP")

            # أفضل الصفقات
            print(f"\n🏆 Best Deals:")
            best_amazon_deal = comparison[comparison['Price_Diff_Amazon_Minus_Noon'] == max_saving_amazon].iloc[0]
            best_noon_deal = comparison[comparison['Price_Diff_Amazon_Minus_Noon'] == max_saving_noon].iloc[0]

            print(f"🔥 Best Amazon deal: {best_amazon_deal['Amazon_Product'][:60]}...")
            print(f"   Amazon: {best_amazon_deal['Amazon_Price']:.0f} EGP, Noon: {best_amazon_deal['Noon_Price']:.0f} EGP, Save: {abs(max_saving_amazon):.0f} EGP")

            print(f"🔥 Best Noon deal: {best_noon_deal['Amazon_Product'][:60]}...")
            print(f"   Amazon: {best_noon_deal['Amazon_Price']:.0f} EGP, Noon: {best_noon_deal['Noon_Price']:.0f} EGP, Save: {abs(max_saving_noon):.0f} EGP")

print("\n💾 Saved files:")
print("- amazon_cleaned_snapshot.csv")
print("- noon_cleaned_snapshot.csv")
print("- Amazon_vs_Noon_comparison.csv")
print("- Amazon_vs_Noon_comparison.xlsx")
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\('
# <>:21: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipython-input-4222385085.py:21: SyntaxWarning: invalid escape sequence '\('
#   mask = ~df.columns.str.contains("src|\(\d+\)|Unnamed|placeholder|image|carousel|link", regex=True, case=False)
# Amazon columns found:
# Product: Product_Name, Price: Price, Rating: Rating, Reviews: Reviews
#
# Noon columns found:
# Product: Product_Name, Price: Price, Old Price: Old_Price, Rating: Rating, Reviews: Reviews
#
# Amazon cleaned: 49 products
# Noon cleaned: 50 products
#
# Matching products with threshold: 70%
#
# ✅ Done. Total matches found: 30
#
# 📊 All matched products (30 products):
#                                        Amazon_Product  \
# 0   Oraimo FreePods 3C (OEB-E104DC), ENC Calling N...
# 1   Soundcore P30i by Anker Noise Cancelling Earbu...
# 2                      Earbuds with Bluetooth Headset
# 3   Soundcore Liberty 4 NC Earbuds, 98.5 Percent N...
# 4   Soundcore By Anker R50i True Wireless Earbuds ...
# 5   JBL Tune 520BT Wireless On-Ear Headphones, Pur...
# 6   Anker soundcore Liberty 4 NC Wireless Noise Ca...
# 7   Earbuds Air31, Wireless, Wired Earphones Trans...
# 8   Soundcore K20i by Anker, Semi-in-Ear Earbuds, ...
# 9   Soundcore By Anker R50i NC True Wireless Earbu...
# 10  HUAWEI FreeBuds SE 2, 40-Hour Battery Life, Co...
# 11  soundcore K20i by Anker, Semi-in-Ear Earbuds, ...
# 12  soundcore Liberty 4 Pro by Anker, Noise Cancel...
# 13  Anker Soundcore R50i Black True Wireless Earbu...
# 14  Anker Soundcore VI R50i True Wireless Earbuds ...
# 15  Oraimo Necklace Lite OEB-311 Neckband Wireless...
# 16  Anker soundcore Liberty 4 NC Wireless, 98.5% N...
# 17  Samsung Galaxy Buds3 Pro, Wireless Bluetooth E...
# 18  Wireless Bluetooth Headphone - Over Ear Stereo...
# 19  Soundcore by Anker Life P2i True Wireless Earb...
# 20  Xiaomi Redmi Buds 4 Active TWS Wireless Earbud...
# 21  HUAWEI FreeBuds 6i, Intelligent Dynamic ANC 3....
# 22  ANKER Soundcore Q11i Wireless Headphones, 40mm...
# 23  فكرة Fekra Compatible with Anker Soundcore R50...
# 24  KM TECHNOLOGY KzaMiza Compatible with Anker So...
# 25  Anker soundcore life u2i bluetooth neckband wi...
# 26  Writiany Silicone Case for Soundcore by Anker ...
# 27  AirPods Pro 2 Plus Bluetooth Headset with Acti...
# 28  Jxrev USB C Headphones,Type C Wired Earbuds, i...
# 29  Wireless Earbuds Bluetooth 5.3 Headphones Deep...
#
#                                          Noon_Product  Match_Score  \
# 0   Oraimo FreePods 3C ENC Calling Noise Cancellat...   100.000000
# 1   Soundcore Soundcore P30i by Anker Noise Cancel...   100.000000
# 2   realme Buds Air 6 True Wireless In-Ear Earbuds...   100.000000
# 3   Soundcore Liberty 4 NC Earbuds, 98.5 Percent N...   100.000000
# 4   Soundcore R50i True Wireless Earbuds 10mm Driv...   100.000000
# 5   JBL Tune 520Bt Wireless On Ear Headphones Pure...    98.360656
# 6   Soundcore Liberty 4 NC Earbuds, 98.5 Percent N...    97.945205
# 7       ANC Wireless Bluetooth Stereo Headphone White    95.348837
# 8   Soundcore Soundcore K20i by Anker, Semi-in-Ear...    95.000000
# 9   Anker Soundcore R50i NC True Wireless Bluetoot...    94.827586
# 10  HUAWEI FreeBuds SE 2 In-ear Earphones, Wireles...    94.000000
# 11  Soundcore Soundcore K20i by Anker, Semi-in-Ear...    92.993631
# 12  Soundcore Liberty 4 Pro by Anker, Noise Cancel...    92.473118
# 13  Soundcore R50i True Wireless Earbuds 10mm Driv...    92.413793
# 14  Anker Soundcore R50i NC True Wireless Bluetoot...    92.035398
# 15  Oraimo Necklace Lite OEB-311 Bluetooth Neckban...    88.732394
# 16  Soundcore Liberty 4 NC Earbuds, 98.5 Percent N...    88.475836
# 17                   Samsung Galaxy Buds 3 Pro Silver    87.719298
# 18      ANC Wireless Bluetooth Stereo Headphone White    87.500000
# 19  Anker Soundcore R50i NC True Wireless Bluetoot...    87.037037
# 20            realme Buds T01 Bluetooth Earbuds White    83.582090
# 21  HUAWEI FreeBuds 6i True Wireless In-ear Earpho...    81.509434
# 22  Soundcore Q11i Wireless Over-Ear Bluetooth Hea...    80.658436
# 23  Anker Soundcore R50i NC True Wireless Bluetoot...    79.207921
# 24  Anker Soundcore R50i NC True Wireless Bluetoot...    79.207921
# 25  Soundcore Anker Soundcore R50i VI Bluetooth Ea...    78.481013
# 26  Anker Soundcore R50i NC True Wireless Bluetoot...    75.510204
# 27  Apple AirPods 4 ANC Wireless Earbuds, Bluetoot...    75.294118
# 28  Generic Pro Air Pods Compatible With Android -...    74.725275
# 29      ANC Wireless Bluetooth Stereo Headphone White    71.428571
#
#     Amazon_Price  Noon_Price  Price_Diff_Amazon_Minus_Noon   Price_Diff_EGP  \
# 0         899.00      934.95                        -35.95     Noon +36 EGP
# 1        1399.00     1399.00                          0.00       Same Price
# 2         338.00     2579.00                      -2241.00   Noon +2241 EGP
# 3        2599.00     2745.00                       -146.00    Noon +146 EGP
# 4         800.16      688.20                        111.96  Amazon +112 EGP
# 5        1855.00     1841.00                         14.00   Amazon +14 EGP
# 6        2949.00     2400.00                        549.00  Amazon +549 EGP
# 7         235.00      398.95                       -163.95    Noon +164 EGP
# 8         675.00      632.05                         42.95   Amazon +43 EGP
# 9        1140.00     1049.00                         91.00   Amazon +91 EGP
# 10       1076.00     1110.00                        -34.00     Noon +34 EGP
# 11        751.86      632.05                        119.81  Amazon +120 EGP
# 12       4340.00     4170.00                        170.00  Amazon +170 EGP
# 13        799.99      688.20                        111.79  Amazon +112 EGP
# 14        863.00     1049.00                       -186.00    Noon +186 EGP
# 15        620.00      729.00                       -109.00    Noon +109 EGP
# 16       2650.00     2431.00                        219.00  Amazon +219 EGP
# 17       5845.00     5788.00                         57.00   Amazon +57 EGP
# 18        189.99      398.95                       -208.96    Noon +209 EGP
# 19        737.47     1049.00                       -311.53    Noon +312 EGP
# 20        583.06      699.00                       -115.94    Noon +116 EGP
# 21       2795.00     2700.00                         95.00   Amazon +95 EGP
# 22       1694.98     1775.00                        -80.02     Noon +80 EGP
# 23         96.00     1049.00                       -953.00    Noon +953 EGP
# 24         73.00     1049.00                       -976.00    Noon +976 EGP
# 25        699.00      868.10                       -169.10    Noon +169 EGP
# 26         59.00     1049.00                       -990.00    Noon +990 EGP
# 27        270.00     9222.00                      -8952.00   Noon +8952 EGP
# 28         95.00      398.95                       -303.95    Noon +304 EGP
# 29        172.00      398.95                       -226.95    Noon +227 EGP
#
#    Best_Option
# 0       Amazon
# 1         Noon
# 2       Amazon
# 3       Amazon
# 4         Noon
# 5         Noon
# 6         Noon
# 7       Amazon
# 8         Noon
# 9         Noon
# 10      Amazon
# 11        Noon
# 12        Noon
# 13        Noon
# 14      Amazon
# 15      Amazon
# 16        Noon
# 17        Noon
# 18      Amazon
# 19      Amazon
# 20      Amazon
# 21        Noon
# 22      Amazon
# 23      Amazon
# 24      Amazon
# 25      Amazon
# 26      Amazon
# 27      Amazon
# 28      Amazon
# 29      Amazon
# === 📈 Comparison Statistics ===
# Total matches: 30
# Average match score: 88.8%
# 📦 Amazon cheaper in: 18 products
# 🛒 Noon cheaper in: 12 products
# ⚖️ Same price in: 1 products
# 💰 Average price difference: -487.39 EGP (Amazon - Noon)
# 💸 Maximum saving on Amazon: 8952 EGP
# 💸 Maximum saving on Noon: 549 EGP
#
# 🏆 Best Deals:
# 🔥 Best Amazon deal: AirPods Pro 2 Plus Bluetooth Headset with Active Noise Cance...
#    Amazon: 270 EGP, Noon: 9222 EGP, Save: 8952 EGP
# 🔥 Best Noon deal: Anker soundcore Liberty 4 NC Wireless Noise Cancelling Earbu...
#    Amazon: 2949 EGP, Noon: 2400 EGP, Save: 549 EGP
#
# 💾 Saved files:
# - amazon_cleaned_snapshot.csv
# - noon_cleaned_snapshot.csv
# - Amazon_vs_Noon_comparison.csv
# - Amazon_vs_Noon_comparison.xlsx
