# %%
# !pip install rapidfuzz --quiet

import pandas as pd, numpy as np, re
from rapidfuzz import process, fuzz
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid", font_scale=1.1)

# تعريف الفايلات
AMAZON_FILE = "amazon_Power_Banks.csv"
NOON_FILE = "noon_Power_Banks.csv"
MATCH_THRESHOLD = 70  # نخفض الثreshold عشان نشوف كل التشابهات
BATCH_SIZE = 6

# قراءة البيانات
amazon = pd.read_csv(AMAZON_FILE)
noon = pd.read_csv(NOON_FILE)

def drop_junk_cols(df):
    """حذف الأعمدة غير المهمة"""
    mask = ~df.columns.str.contains("src|\(\d+\)|Unnamed|placeholder|image|carousel|link", regex=True, case=False)
    return df.loc[:, mask]

def find_column_like(df, patterns):
    """الباحث عن الأعمدة بناء على أنماط"""
    cols = df.columns.tolist()
    for p in patterns:
        for c in cols:
            if p.lower() in c.lower():
                return c
    text_cols = [c for c in cols if df[c].dtype == object]
    if text_cols:
        return text_cols[0]
    return None

def clean_numeric_series(s):
    """تنظيف البيانات الرقمية"""
    if s is None:
        return pd.Series([np.nan] * len(s))
    s = s.astype(str).str.replace(",", "", regex=False).str.strip()
    extracted = s.str.extract(r"([0-9]+(?:\.[0-9]+)?)")[0]
    return pd.to_numeric(extracted, errors="coerce")

def normalize_product_name(s):
    """توحيد تنسيق أسماء المنتجات"""
    s = str(s).lower()
    s = re.sub(r"package(ing)? may vary", " ", s)
    s = re.sub(r"\b(\d+\s*(ml|g|gm|kg|l|oz|cm|mm))\b", " ", s)
    s = re.sub(r"\b(ml|g|gm|kg|l|oz|pack|packs|pcs|piece|pieces|box|set)\b", " ", s)
    s = re.sub(r"[^a-z0-9\s]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

# تنظيف البيانات
amazon = drop_junk_cols(amazon)
noon = drop_junk_cols(noon)

# تحديد الأعمدة
a_product_col = find_column_like(amazon, ["product","title","name"])
a_price_col = find_column_like(amazon, ["price"])
a_rating_col = find_column_like(amazon, ["rating"])
a_reviews_col = find_column_like(amazon, ["reviews","review"])

n_product_col = find_column_like(noon, ["product","title","name"])
n_price_col = find_column_like(noon, ["price"])
n_old_col = find_column_like(noon, ["old_price","old"])
n_rating_col = find_column_like(noon, ["rating"])
n_reviews_col = find_column_like(noon, ["reviews","review"])

print("Amazon columns found:")
print(f"Product: {a_product_col}, Price: {a_price_col}, Rating: {a_rating_col}, Reviews: {a_reviews_col}")
print("\nNoon columns found:")
print(f"Product: {n_product_col}, Price: {n_price_col}, Old Price: {n_old_col}, Rating: {n_rating_col}, Reviews: {n_reviews_col}")

# تنظيف بيانات Amazon
amazon_clean = pd.DataFrame()
amazon_clean['Product_raw'] = amazon[a_product_col] if a_product_col else amazon.iloc[:, 3]  # العمود الرابع بيكون Product_Name
amazon_clean['Price_raw'] = amazon[a_price_col] if a_price_col else amazon.iloc[:, 6]  # العمود السابع بيكون Price
amazon_clean['Rating_raw'] = amazon[a_rating_col] if a_rating_col else amazon.iloc[:, 4]  # العمود الخامس بيكون Rating
amazon_clean['Reviews_raw'] = amazon[a_reviews_col] if a_reviews_col else amazon.iloc[:, 5]  # العمود السادس بيكون Reviews

# تنظيف بيانات Noon
noon_clean = pd.DataFrame()
noon_clean['Product_raw'] = noon[n_product_col] if n_product_col else noon.iloc[:, 3]  # العمود الرابع بيكون Product_Name
noon_clean['Price_raw'] = noon[n_price_col] if n_price_col else noon.iloc[:, 6]  # العمود السابع بيكون Price
noon_clean['OldPrice_raw'] = noon[n_old_col] if n_old_col else noon.iloc[:, 7]  # العمود الثامن بيكون Old_Price
noon_clean['Rating_raw'] = noon[n_rating_col] if n_rating_col else noon.iloc[:, 4]  # العمود الخامس بيكون Rating
noon_clean['Reviews_raw'] = noon[n_reviews_col] if n_reviews_col else noon.iloc[:, 5]  # العمود السادس بيكون Reviews

# تطبيع أسماء المنتجات
amazon_clean['Product_norm'] = amazon_clean['Product_raw'].fillna("").map(normalize_product_name)
noon_clean['Product_norm'] = noon_clean['Product_raw'].fillna("").map(normalize_product_name)

# تنظيف البيانات الرقمية
amazon_clean['Price'] = clean_numeric_series(amazon_clean['Price_raw'])
amazon_clean['Rating'] = clean_numeric_series(amazon_clean['Rating_raw'])
amazon_clean['Reviews'] = clean_numeric_series(amazon_clean['Reviews_raw'])

noon_clean['Price'] = clean_numeric_series(noon_clean['Price_raw'])
noon_clean['Old_Price'] = clean_numeric_series(noon_clean['OldPrice_raw'])
noon_clean['Rating'] = clean_numeric_series(noon_clean['Rating_raw'])
noon_clean['Reviews'] = clean_numeric_series(noon_clean['Reviews_raw'])

print(f"\nAmazon cleaned: {len(amazon_clean)} products")
print(f"Noon cleaned: {len(noon_clean)} products")

# عمل المطابقة بين المنتجات - بنخفض الثreshold عشان نشوف كل التشابهات
noon_choices = noon_clean['Product_norm'].fillna("").tolist()
results = []

print(f"\nMatching products with threshold: {MATCH_THRESHOLD}%")

for idx, row in amazon_clean.iterrows():
    a_name = row['Product_norm']
    if not a_name.strip():
        continue

    match = process.extractOne(a_name, noon_choices, scorer=fuzz.token_set_ratio)
    if match is None:
        continue

    best_name, score, match_index = match
    if score < MATCH_THRESHOLD:
        continue

    n_row = noon_clean.iloc[match_index]
    a_price = row['Price'] if not pd.isna(row['Price']) else np.nan
    n_price = n_row['Price'] if not pd.isna(n_row['Price']) else np.nan

    # حساب فرق السعر (Amazon - Noon)
    price_diff = (a_price - n_price) if (not np.isnan(a_price) and not np.isnan(n_price)) else np.nan

    # تحديد الأفضل بناء على السعر
    if np.isnan(price_diff):
        if not np.isnan(a_price) and np.isnan(n_price):
            best_opt = "Amazon"
        elif np.isnan(a_price) and not np.isnan(n_price):
            best_opt = "Noon"
        else:
            best_opt = "Unknown"
    else:
        best_opt = "Amazon" if a_price < n_price else "Noon"

    results.append({
        "Amazon_idx": idx,
        "Noon_idx": match_index,
        "Amazon_Product": row['Product_raw'],
        "Amazon_Price": a_price,
        "Amazon_Rating": row['Rating'],
        "Amazon_Reviews": row['Reviews'],
        "Noon_Product": n_row['Product_raw'],
        "Noon_Price": n_price,
        "Noon_Old_Price": n_row['Old_Price'],
        "Noon_Rating": n_row['Rating'],
        "Noon_Reviews": n_row['Reviews'],
        "Match_Score": score,
        "Price_Diff_Amazon_Minus_Noon": price_diff,  # الكولوم الجديد
        "Best_Option": best_opt
    })

# إنشاء DataFrame النهائي
comparison = pd.DataFrame(results).sort_values("Match_Score", ascending=False).reset_index(drop=True)

# إضافة عمود يوضح فرق السعر بشكل أوضح
comparison['Price_Diff_EGP'] = comparison['Price_Diff_Amazon_Minus_Noon'].apply(
    lambda x: f"Amazon +{abs(x):.0f} EGP" if x > 0 else f"Noon +{abs(x):.0f} EGP" if x < 0 else "Same Price" if x == 0 else "N/A"
)

# حفظ النتائج
comparison.to_csv("Amazon_vs_Noon_PowerBanks_comparison.csv", index=False)
comparison.to_excel("Amazon_vs_Noon_PowerBanks_comparison.xlsx", index=False)

print(f"\n✅ Done. Total matches found: {len(comparison)}")
print(f"\n📊 All matched Power Banks ({len(comparison)} products):")

# عرض كل المنتجات المتشابهة
display(comparison[[
    'Amazon_Product',
    'Noon_Product',
    'Match_Score',
    'Amazon_Price',
    'Noon_Price',
    'Price_Diff_Amazon_Minus_Noon',
    'Price_Diff_EGP',
    'Best_Option'
]])

# دالة لعرض الرسوم البيانية
def plot_batches(df, batch_size=6):
    names = df["Amazon_Product"].astype(str).tolist()
    a_prices = df["Amazon_Price"].tolist()
    n_prices = df["Noon_Price"].tolist()
    price_diffs = df["Price_Diff_Amazon_Minus_Noon"].tolist()

    for i in range(0, len(names), batch_size):
        batch_names = names[i:i+batch_size]
        batch_a = a_prices[i:i+batch_size]
        batch_n = n_prices[i:i+batch_size]
        batch_diffs = price_diffs[i:i+batch_size]

        y = np.arange(len(batch_names))
        height = 0.35

        plt.figure(figsize=(14, max(5, len(batch_names)*0.9)))
        bars_a = plt.barh(y - height/2, batch_a, height=height, label="Amazon", color="#1f77b4", alpha=0.7)
        bars_n = plt.barh(y + height/2, batch_n, height=height, label="Noon", color="#ff7f0e", alpha=0.7)

        plt.yticks(y, [name[:50] + "..." if len(name) > 50 else name for name in batch_names], fontsize=8)
        plt.xlabel("Price (EGP)")
        plt.title(f"Amazon vs Noon Power Banks Price Comparison - Batch {i//batch_size + 1}\n(Items {i+1}-{i+len(batch_names)}, Match Score: {df.iloc[i]['Match_Score']:.0f}%)")

        # إضافة القيم على الأعمدة
        for yi, av, nv, diff in zip(y, batch_a, batch_n, batch_diffs):
            if not pd.isna(av):
                plt.text(av, yi - height/2, f" {av:.0f}", va="center", fontsize=7, fontweight='bold')
            if not pd.isna(nv):
                plt.text(nv, yi + height/2, f" {nv:.0f}", va="center", fontsize=7, fontweight='bold')

            # إضافة فرق السعر في المنتصف
            if not pd.isna(diff):
                mid_x = min(av, nv) + abs(diff)/2
                color = "green" if diff < 0 else "red" if diff > 0 else "blue"
                plt.text(mid_x, yi, f"Δ={diff:.0f}", va="center", ha="center",
                        fontsize=8, fontweight='bold', color=color, bbox=dict(boxstyle="round,pad=0.2", facecolor="white", alpha=0.8))

        plt.legend()
        plt.tight_layout()
        plt.show()

# عرض الرسوم البيانية إذا وجدت نتائج
if not comparison.empty:
    plot_df = comparison.sort_values("Match_Score", ascending=False).reset_index(drop=True)
    plot_batches(plot_df, batch_size=BATCH_SIZE)

    # إحصائيات إضافية
    print("\n=== 📈 Power Banks Comparison Statistics ===")
    print(f"Total matches: {len(comparison)}")
    print(f"Average match score: {comparison['Match_Score'].mean():.1f}%")

    amazon_cheaper = len(comparison[comparison['Best_Option'] == 'Amazon'])
    noon_cheaper = len(comparison[comparison['Best_Option'] == 'Noon'])
    same_price = len(comparison[(comparison['Price_Diff_Amazon_Minus_Noon'] == 0) & (~comparison['Price_Diff_Amazon_Minus_Noon'].isna())])

    print(f"📦 Amazon cheaper in: {amazon_cheaper} power banks")
    print(f"🛒 Noon cheaper in: {noon_cheaper} power banks")
    print(f"⚖️ Same price in: {same_price} power banks")

    if len(comparison) > 0:
        valid_diffs = comparison['Price_Diff_Amazon_Minus_Noon'].dropna()
        if len(valid_diffs) > 0:
            avg_price_diff = valid_diffs.mean()
            max_saving_amazon = valid_diffs.min()  # أكثر فرق إيجابي لصالح Amazon
            max_saving_noon = valid_diffs.max()    # أكثر فرق إيجابي لصالح Noon

            print(f"💰 Average price difference: {avg_price_diff:.2f} EGP (Amazon - Noon)")
            print(f"💸 Maximum saving on Amazon: {abs(max_saving_amazon):.0f} EGP")
            print(f"💸 Maximum saving on Noon: {abs(max_saving_noon):.0f} EGP")

            # أفضل الصفقات
            print(f"\n🏆 Best Power Bank Deals:")
            best_amazon_deal = comparison[comparison['Price_Diff_Amazon_Minus_Noon'] == max_saving_amazon].iloc[0]
            best_noon_deal = comparison[comparison['Price_Diff_Amazon_Minus_Noon'] == max_saving_noon].iloc[0]

            print(f"🔥 Best Amazon deal: {best_amazon_deal['Amazon_Product'][:60]}...")
            print(f"   Amazon: {best_amazon_deal['Amazon_Price']:.0f} EGP, Noon: {best_amazon_deal['Noon_Price']:.0f} EGP, Save: {abs(max_saving_amazon):.0f} EGP")

            print(f"🔥 Best Noon deal: {best_noon_deal['Amazon_Product'][:60]}...")
            print(f"   Amazon: {best_noon_deal['Amazon_Price']:.0f} EGP, Noon: {best_noon_deal['Noon_Price']:.0f} EGP, Save: {abs(max_saving_noon):.0f} EGP")

print("\n💾 Saved files:")
print("- Amazon_vs_Noon_PowerBanks_comparison.csv")
print("- Amazon_vs_Noon_PowerBanks_comparison.xlsx")
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\('
# <>:21: SyntaxWarning: invalid escape sequence '\('
# /tmp/ipython-input-783070160.py:21: SyntaxWarning: invalid escape sequence '\('
#   mask = ~df.columns.str.contains("src|\(\d+\)|Unnamed|placeholder|image|carousel|link", regex=True, case=False)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 16.5 MB/s eta 0:00:00
# Amazon columns found:
# Product: Product_Name, Price: Price, Rating: Rating, Reviews: Reviews
#
# Noon columns found:
# Product: Product_Name, Price: Price, Old Price: Old_Price, Rating: Rating, Reviews: Reviews
#
# Amazon cleaned: 43 products
# Noon cleaned: 47 products
#
# Matching products with threshold: 70%
#
# ✅ Done. Total matches found: 34
#
# 📊 All matched Power Banks (34 products):
#                                        Amazon_Product  \
# 0   Anker Zolo Power Bank (25K, 165W, Built-In USB...
# 1   ANKER Zolo Magnetic Power Bank, 10,000mAh Wire...
# 2   Oraimo Slice Link Pro 22.5W Super Fast Chargin...
# 3   Anker Zolo Power Bank, 10,000mAh 30W Max Fast ...
# 4   Anker Zolo Power Bank, 10,000 mAh 30W Max Fast...
# 5   Anker MagGo Power Bank, 15W Ultra-Fast Portabl...
# 6   Anker Zolo Magnetic Power Bank, Compact 10,000...
# 7   Joyroom W050 20W Magnetic Wireless Power Bank ...
# 8   Anker Power Bank 10000mAh 22.5W Portable Charg...
# 9   UGREEN 10000mAh 30W Two-way Fast Charging Powe...
# 10  Joyroom JR-QP193 30000mAh 22.5W fast charging ...
# 11        Joyroom PBF02 30W Power Bank 20000mAh-Black
# 12  Anker Laptop Power Bank (25,000 mAh, 165W, Bui...
# 13  Anker 633 Magnetic Battery, 10,000mAh Foldable...
# 14  ANKER PowerCore Slim 10000mAh Power Bank A1229...
# 15  Joyroom JR-W020 20W Magnetic Wireless Power Ba...
# 16  Joyroom JR-PBF12 2.4A 10000mAh LED Power Bank,...
# 17        1500mAh Portable Mini Power Bank for iPhone
# 18  Xiaomi Redmi Power Bank 20000mAh – 18W Two-Way...
# 19  Anker Zolo Powerbank, Built-in Type-C and Ligh...
# 20  Oraimo Travaler 22.5 PD 20000mAh Power Bank wi...
# 21  WIWU Speedy Series Power Bank 10000mAh PD & QC...
# 22  Joyroom JR-PBF15 22.5W 10000mAh LED Fast Charg...
# 23  Joyroom. W050 20W Magnetic Wireless Power Bank...
# 24  Anker 324 Power Bank 10,000 mAh with 2 Ports (...
# 25  Joyroom JR-T012 Top star mobile power 10000mAh...
# 26  ANKER 621 7.5W (mag-GO) 5K MAH Magnetic Wirele...
# 27  Joyroom JR-PBF12 2.4A LED 22.5W Power Bank 200...
# 28  Anker Powercore Metro Essential 20000 Pd Porta...
# 29  Choetech B735 20W Magnetic Power Bank, Built-I...
# 30  Anker Power Bank 10,000 mAh, 533 PowerCore wit...
# 31  G-Power Brilliance 10000mAh Power Bank, 37W Fa...
# 32  G-Power GP-PB011 Led Screen 10000mAh Power Ban...
# 33  G-Power GP-PB010 Led Screen 10000mAh Power Ban...
#
#                                          Noon_Product  Match_Score  \
# 0   Anker Anker Zolo Power Bank (25K, 165W, Built-...   100.000000
# 1   Anker 10000 mAh Zolo Magnetic Power Bank, Wire...    98.333333
# 2   Oraimo 10000 mAh 22.5W Super Fast Charging, Sl...    95.384615
# 3   Anker Zolo Power Bank, 10,000mAh 30W Max Fast ...    94.904459
# 4   Anker Zolo Power Bank, 20,000mAh 30W Max Fast ...    93.452381
# 5   Anker MagGo Power Bank-Qi2 Certified 15W Ultra...    93.382353
# 6   Anker Zolo Magnetic Power Bank, Compact 10,000...    92.715232
# 7   JOYROOM 10000.0 mAh JR-W050 20W PD3.0 Fast Cha...    89.208633
# 8   Anker 10000 mAh Powercore Power Bank 22.5W Por...    87.500000
# 9   Ugreen 20000 mAh UGREEN 20000mAh 20W Two-way F...    87.096774
# 10  JOYROOM 22.5W Ultra Fast Charging PowerBank (6...    86.956522
# 11  JOYROOM JR-QP192 20000mAh 22.5W Ultra Fast Cha...    86.842105
# 12  Anker Anker Zolo Power Bank (25K, 165W, Built-...    85.981308
# 13  Anker Zolo Magnetic Power Bank, Compact 10,000...    84.615385
# 14  Anker Power Bank, USB-C Portable Charger 10000...    84.210526
# 15  JOYROOM JR-W020 20W Mini Magnetic Wireless Pow...    83.443709
# 16  JOYROOM 10000 mAh JR-PBF12 2.4A LED Power Bank...    82.758621
# 17  Anker Zolo Magnetic Power Bank, Compact 10,000...    82.191781
# 18  Matrix S20-20000mAh Power Bank Fast Charging 2...    82.105263
# 19  Anker Zolo Power Bank, 20,000mAh 30W Max Fast ...    80.351906
# 20  Matrix S20-20000mAh Power Bank Fast Charging 2...    78.260870
# 21  Matrix S20-20000mAh Power Bank Fast Charging 2...    78.260870
# 22  Matrix S20-20000mAh Power Bank Fast Charging 2...    78.260870
# 23  JOYROOM 10000 mAh JR-PBM08 Pro 20W magnetic wi...    77.777778
# 24  JOYROOM 10000 mAh JR-PBF12 2.4A LED Power Bank...    77.551020
# 25  JOYROOM 10000 mAh JR-PBF20 25W digital fast ch...    76.190476
# 26  Anker 10000 mAh Zolo Magnetic Power Bank, Wire...    76.106195
# 27  JOYROOM 20000 mAh 20000 mAh 22.5W JR-PBF16 200...    75.409836
# 28  Anker 10000 mAh Powercore Power Bank 22.5W Por...    75.000000
# 29  Anker 10000 mAh Zolo Magnetic Power Bank, Wire...    74.509804
# 30  Anker Power Bank, 533 Power Bank (PowerCore 30...    74.208145
# 31  rsilou R1003-001 10000mAh Capacity Power Bank,...    73.619632
# 32  Matrix S20-20000mAh Power Bank Fast Charging 2...    71.264368
# 33  Matrix S20-20000mAh Power Bank Fast Charging 2...    71.264368
#
#     Amazon_Price  Noon_Price  Price_Diff_Amazon_Minus_Noon    Price_Diff_EGP  \
# 0        3888.00     3899.00                        -11.00      Noon +11 EGP
# 1        1850.00     1799.00                         51.00    Amazon +51 EGP
# 2         698.00      899.00                       -201.00     Noon +201 EGP
# 3        1577.00     1550.00                         27.00    Amazon +27 EGP
# 4        1520.00     2150.00                       -630.00     Noon +630 EGP
# 5        5928.00     8199.00                      -2271.00    Noon +2271 EGP
# 6        1599.00     1650.00                        -51.00      Noon +51 EGP
# 7        1099.00     1390.00                       -291.00     Noon +291 EGP
# 8        1299.00     1163.00                        136.00   Amazon +136 EGP
# 9        1620.00     1815.00                       -195.00     Noon +195 EGP
# 10       1288.00     1400.00                       -112.00     Noon +112 EGP
# 11       1408.48      998.95                        409.53   Amazon +410 EGP
# 12       4290.00     3899.00                        391.00   Amazon +391 EGP
# 13       2999.00     1650.00                       1349.00  Amazon +1349 EGP
# 14       1139.66     2900.00                      -1760.34    Noon +1760 EGP
# 15       1025.00      899.00                        126.00   Amazon +126 EGP
# 16        490.00      693.30                       -203.30     Noon +203 EGP
# 17        265.94     1650.00                      -1384.06    Noon +1384 EGP
# 18       1029.00      950.00                         79.00    Amazon +79 EGP
# 19       1666.00     2150.00                       -484.00     Noon +484 EGP
# 20        899.00      950.00                        -51.00      Noon +51 EGP
# 21        399.00      950.00                       -551.00     Noon +551 EGP
# 22        704.19      950.00                       -245.81     Noon +246 EGP
# 23       1100.00     1237.00                       -137.00     Noon +137 EGP
# 24        999.00      693.30                        305.70   Amazon +306 EGP
# 25        999.00      798.00                        201.00   Amazon +201 EGP
# 26       1289.99     1799.00                       -509.01     Noon +509 EGP
# 27        759.00      903.85                       -144.85     Noon +145 EGP
# 28       2999.00     1163.00                       1836.00  Amazon +1836 EGP
# 29        999.00     1799.00                       -800.00     Noon +800 EGP
# 30       1738.88     1399.00                        339.88   Amazon +340 EGP
# 31        299.00      674.00                       -375.00     Noon +375 EGP
# 32        399.00      950.00                       -551.00     Noon +551 EGP
# 33        470.00      950.00                       -480.00     Noon +480 EGP
#
#    Best_Option
# 0       Amazon
# 1         Noon
# 2       Amazon
# 3         Noon
# 4       Amazon
# 5       Amazon
# 6       Amazon
# 7       Amazon
# 8         Noon
# 9       Amazon
# 10      Amazon
# 11        Noon
# 12        Noon
# 13        Noon
# 14      Amazon
# 15        Noon
# 16      Amazon
# 17      Amazon
# 18        Noon
# 19      Amazon
# 20      Amazon
# 21      Amazon
# 22      Amazon
# 23      Amazon
# 24        Noon
# 25        Noon
# 26      Amazon
# 27      Amazon
# 28        Noon
# 29      Amazon
# 30        Noon
# 31      Amazon
# 32      Amazon
# 33      Amazon
# === 📈 Power Banks Comparison Statistics ===
# Total matches: 34
# Average match score: 83.2%
# 📦 Amazon cheaper in: 22 power banks
# 🛒 Noon cheaper in: 12 power banks
# ⚖️ Same price in: 0 power banks
# 💰 Average price difference: -181.98 EGP (Amazon - Noon)
# 💸 Maximum saving on Amazon: 2271 EGP
# 💸 Maximum saving on Noon: 1836 EGP
#
# 🏆 Best Power Bank Deals:
# 🔥 Best Amazon deal: Anker MagGo Power Bank, 15W Ultra-Fast Portable Charger Comp...
#    Amazon: 5928 EGP, Noon: 8199 EGP, Save: 2271 EGP
# 🔥 Best Noon deal: Anker Powercore Metro Essential 20000 Pd Portable Charger, 2...
#    Amazon: 2999 EGP, Noon: 1163 EGP, Save: 1836 EGP
#
# 💾 Saved files:
# - Amazon_vs_Noon_PowerBanks_comparison.csv
# - Amazon_vs_Noon_PowerBanks_comparison.xlsx
